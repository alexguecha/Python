# %% [markdown]
# <a href="https://colab.research.google.com/github/alexguecha/Python/blob/main/Cuaderno_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Curso de Programación en Analítica de Datos**

# %%
nombre = input("¿Por favor digitas tu nombre?:")
print("¡Bienvenido " + nombre + "!")
# Out:
# ¿Por favor digitas tu nombre?:Alexander
# ¡Bienvenido Alexander!

# %% [markdown]
# # **Bienvenido a la Rama Judicial**
# ![Rama.JPG](data:image/jpeg;base64,...)
# ## Sobre la Rama Judicial
# A la Rama Judicial le corresponde administrar justicia, solucionar los conflictos y controversias entre los ciudadanos y entre éstos y el Estado y decidir cuestiones jurídicas controvertidas mediante pronunciamientos que adquieren fuerza de verdad definitiva. Dichos pronunciamientos toman principalmente la forma de sentencias, fallos, o autos.
#
#
# [wwww.ramajudicial.gov.co](https://www.ramajudicial.gov.co)

# %% [markdown]
# # **Estadísticas Judiciales 2021**
#
# ## Jurisdicción Ordinaria
# ### Especialidad Penal:
# En la especialidad penal se presenta la siguiente demanda de justicia:
#
# distrito  | Total Ingresos 2021
# -------------------|------------------
# Bogotá             | 1500000
# Antioquia          | 896321
#
#
# ### Tutelas:
# La tutela presenta ha presentado una mayor demanda para el 2021, como se detalla a continuación:
#
# distrito  | Total Ingresos 2021
# -------------------|------------------
# Bogotá             | 2000000
# Antioquia          | 1300000

# %% [markdown]
# #**Indicadores**
#
# ##*Índice de Evacuación Parcial*
#
# ```markdown
# El índice de evacuación parcial está dada por la siguiente fórmula:
#
# ```
# ```python
# EGRESO=500
# INVENTARIOFINAL=85
#
# IEP = EGRESO/INVENTARIOFINAL**2
#
# print(IEP)
#
#
# ```
#
# $IEP = EGRESOS / INVENTARIO FINAL^2$

# %%
EGRESO=500
INVENTARIOFINAL=85

IEP = EGRESO/INVENTARIOFINAL**2

print(IEP)
# Out:
# 0.06920415224913495

# %% [markdown]
# #**Jurisdicciones de la Rama Judicial**
#
# *   Jurisdicción Ordinaria
#
# *   Jurisdicción Contencioso Administrativo
# *   Jurisdicción Constitucional
# *   Jurisdicción Disciplinaria
#
# #**Total de ingresos  durante el año 2021**
#
# Jurisdicción          | Total Ingresos 2021
# -------------------   |-----------------------------------
# Ordinaria             | 2800000
# Contencioso Administrativo          | 1300000
# Constitucional|2000000|5000000
# Disciplinaria|900000|90000
